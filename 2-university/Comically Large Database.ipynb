# %% [markdown]
# ![Screenshot 2025-03-26 181814.png](data:image/png;base64,...)

# %%
# This works, but it's useless
# !apt install php

# !nohup php -S localhost:8000 > server.log 2>&1 &

# !curl http://localhost:443/index.php
# Out:
#   File "<ipython-input-1-bbae3c563064>", line 4
#     <title>Instructor's Courses</title>
#                      ^
# SyntaxError: unterminated string literal (detected at line 4)

# %%
# This works
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# This doesn't work

import subprocess

# if the script don't need output.
subprocess.call("php /content/drive/MyDrive/25SP/COP-3710-03/Comically Large Database/Ben's_index.php")

# if you want output
proc = subprocess.Popen("php /content/drive/MyDrive/25SP/COP-3710-03/Comically Large Database/Ben's_index.php", shell=True, stdout=subprocess.PIPE)
script_response = proc.stdout.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-4bd26c405413> in <cell line: 0>()
#       2
#       3 # if the script don't need output.
# ----> 4 subprocess.call("php /content/drive/MyDrive/25SP/COP-3710-03/Comically Large Database/Ben's_index.php")
#       5
#       6 # if you want output
#
# /usr/lib/python3.11/subprocess.py in call(timeout, *popenargs, **kwargs)
#     387     retcode = call(["ls", "-l"])
#     388     """
# --> 389     with Popen(*popenargs, **kwargs) as p:
#     390         try:
#     391             return p.wait(timeout=timeout)
#
# ...

# %%
#PHP here
# Out:
# Mounted at /content/drive
